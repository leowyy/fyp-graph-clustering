# %%
import os
os.chdir('..')
os.getcwd()
# Out:
# '/Users/signapoop/Desktop/fyp-graph-clustering'

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

from sklearn.datasets import fetch_20newsgroups_vectorized
from util.plot_embedding import plot_embedding, plot_embedding_subplot
from core.DimReduction import DimReduction

# Memorized fetch_rcv1 for faster access
dataset = fetch_20newsgroups_vectorized('all')
X = dataset.data
y = dataset.target

# %%
X.shape
# Out:
# (18846, 130107)

# %%
y.shape
# Out:
# (18846,)

# %%
X_small = X[:5000]
y_small = y[:5000]

# %%
dim_red = DimReduction(n_components=1000)

# %%
X_emb = dim_red.fit_transform(X_small.todense(), 'pca')

# %%
X_emb.shape
# Out:
# (5000, 1000)

# %%
dim_red = DimReduction(n_components=2)
X_emb2 = dim_red.fit_transform(X_emb, 'tsne')

# %%
f, ax = plt.subplots(1,1, sharex='col', sharey='row', figsize=(6, 6))
plot_embedding_subplot(ax, X_emb2[:500], labels=y_small[:500], title='tsne')
