# %%
import os
os.chdir('..')
os.getcwd()

# %%
import core.block as block
from core.SemiSuperCluGraph import SemiSuperCluGraph

# %%
# %matplotlib inline
import networkx as nx
import numpy as np

# %%
task_parameters = {}
task_parameters['flag_task'] = 'clustering'
task_parameters['nb_communities'] = 5
task_parameters['nb_clusters_target'] = task_parameters['nb_communities']
task_parameters['Voc'] = task_parameters['nb_communities'] + 1
task_parameters['size_min'] = 5
task_parameters['size_max'] = 10
task_parameters['p'] = 0.5
task_parameters['q'] = 0.1

# %%
train_x = SemiSuperCluGraph(task_parameters)

# %%
G = nx.from_numpy_matrix(train_x.adj_matrix)

# %%
classes = list(train_x.target)

# %%
nx.draw_spring(G, node_color=classes)

# %%
task_parameters['p'] = 0.8
task_parameters['q'] = 0.05

# %%
train_x = SemiSuperCluGraph(task_parameters)
G = nx.from_numpy_matrix(train_x.adj_matrix)
classes = list(train_x.target)
nx.draw_spring(G, node_color=classes)
